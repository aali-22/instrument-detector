# %% [markdown]
# # 🎸 InstruDetector – Instrument Classification via Spectrograms + CNN
#
# This project converts audio files into mel spectrograms and trains a convolutional neural network to classify instruments (e.g., violin, piano, electric guitar, acoustic guitar).
#
# - **Data:** Filtered subset of NSynth
# - **Goal:** Achieve high accuracy while maintaining a clean, understandable ML pipeline.

# %%
# Imports & Setup
import torch
import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os, random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ## 📉 Confusion Matrix & Classification Report

# %%
# Assuming model and validation dataloader are ready
model.load_state_dict(torch.load('outputs/best_model.pt', map_location=device))
model.eval()

all_preds, all_labels = [], []
with torch.no_grad():
    for xb, yb in valid_loader:
        xb = xb.to(device)
        preds = model(xb).argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=list(train_ds.label_map.keys()))
disp.plot(cmap='Blues')
plt.title('Validation Confusion Matrix')
plt.show()

print(classification_report(all_labels, all_preds, target_names=list(train_ds.label_map.keys())))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Assuming model and validation dataloader are ready
# ----> 2 model.load_state_dict(torch.load('outputs/best_model.pt', map_location=device))
#       3 model.eval()
#       5 all_preds, all_labels = [], []
#
# NameError: name 'model' is not defined
